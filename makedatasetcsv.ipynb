# %%
import cv2
import mediapipe as mp
import pandas as pd

# %%
# Create a pose object
mp_pose = mp.solutions.pose

# Initialize the pose model
pose = mp_pose.Pose()

# %%
# Create a video capture object
cap = cv2.VideoCapture(0)

# Loop until the user presses 'q'
while True:
    # Read a frame from the camera
    ret, frame = cap.read()

    # Convert the frame to RGB format
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with the pose model
    results = pose.process(rgb)

    # Check if there are any poses detected
    if results.pose_landmarks:
        # Get the pose landmarks for each person
        for person in results.pose_landmarks_list:
            # Convert the landmarks to a list of tuples (x,y,z)
            landmarks = [(lm.x, lm.y, lm.z) for lm in person.landmark]

            # Convert the landmarks to a dataframe
            df = pd.DataFrame(landmarks)

            # Save the dataframe as a CSV file with a unique name
            df.to_csv(f'pose_{id(person)}.csv', index=False)

    # Show the frame on the screen
    cv2.imshow('Webcam', frame)

    # Check if the user pressed 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 18
#      15 # Check if there are any poses detected
#      16 if results.pose_landmarks:
#      17     # Get the pose landmarks for each person
# ---> 18     for person in results.pose_landmarks_list:
#      19         # Convert the landmarks to a list of tuples (x,y,z)
#      20         landmarks = [(lm.x, lm.y, lm.z) for lm in person.landmark]
#      22         # Convert the landmarks to a dataframe
#
# AttributeError: type object 'SolutionOutputs' has no attribute 'pose_landmarks_list'
